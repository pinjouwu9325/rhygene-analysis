# %% [markdown]
# # Identify rhythmic genes of datasets without time annotation
#
# ### Tools: CYCLOPS
# CYCLOPS reveals human transcriptional rhythms Ron C. Anafi, Lauren J. Francey, John B. Hogenesch, Junhyong Kim Proceedings of the National Academy of Sciences May 2017, 114 (20) 5312-5317; DOI: 10.1073/pnas.1619320114
#
# ### Dataset: GTEx Lung (version 8)
#
# ### Seed genes: Baboon genes cyclying in more than 20 tissues
# Diurnal transcriptome atlas of a primate across major neural and peripheral tissues
# BY LUDOVIC S. MURE, HIEP D. LE, GIORGIA BENEGIAMO, MAX W. CHANG, LUIS RIOS, NGALLA JILLANI, MAINA NGOTHO, THOMAS KARIUKI, OURIA DKHISSI-BENYAHYA, HOWARD M. COOPER, SATCHIDANANDA PANDA, SCIENCE16 MAR 2018

# %% [markdown]
# ## Import packages and modules used in CYCLOPS
# Note: Change in addprocs() does not affect the number of procosser used because the function in module scripts are written for 5 processors according to Dr. Anafi's machine. If would like to change the number of processor used in CYCLOPS, edit the module script as well.

# %%
# Add processor
addprocs(5)

# Set working directory for each processor
@everywhere basedir = homedir()
@everywhere workdir = string(basedir, "/circa/CYCLOPS/baboon")
@everywhere cd(workdir)

using StatsBase
using MultivariateStats
using Distributions

@everywhere include("CYCLOPS_v6_2a_AutoEncoderModule_multi.jl")
@everywhere include("CYCLOPS_v6_2a_Seed.jl")
@everywhere include("CYCLOPS_v6_2a_PreNPostprocessModule.jl")
@everywhere include("CYCLOPS_v6_2a_CircularStats_U.jl")
@everywhere include("CYCLOPS_v6_2a_MultiCoreModule_Smooth.jl")



using CYCLOPS_v6_2a_AutoEncoderModule_multi
using CYCLOPS_v6_2a_Seed
using CYCLOPS_v6_2a_PreNPostprocessModule
using CYCLOPS_v6_2a_CircularStats_U
using CYCLOPS_v6_2a_MultiCoreModule_Smooth

# datadir = string("/circa/CYCLOPS/baboon")
# seeddir = string("/circa/CYCLOPS/baboon")

# %% [markdown]
# ## Load datasets and seed gene list
# * **Dataset**: Each row represents a gene, and each column represents a sample.
#   * The first row is the header **[1,:]**.
#   * The second column is gene symbol **[:,2]**
#   * The expression data strat from the fourth coulmn **[2:end, 4:end]**.
# * **Seed gene list**: Choose a good seed gene list is quite tricky. According to the suggestion from Dr. Anafi: The seed genes are supposed to reflect a "best guess" at the transcripts that will show circadian oscillations in the tissue being sorted. I do think using the seed list from the human data is a good way to go.
#   * Seed gene list is a two dimentions array with all the seed genes stored at the secondary column **[2:end, 2]**.

# %%
# Load dataset
# cd(datadir)
data = readcsv("gtexExpr_ba9.gct")

# Laod seed gene list
# cd(seeddir)
seed= readcsv("CircaGenes_baboon_edited.txt")
seed_list = seed[2:end,2]

cd(workdir)

# %% [markdown]
# ## Set parameter
# * **Frac_Var**: Set Number of Dimensions of SVD to maintain this fraction of variance
# * **DFrac_Var**: Set Number of Dimensions of SVD to so that incremetal fraction of variance of var is at least this much
# * **N_trials**: Number of random initial conditions to try for each optimization
# * **MaxSeeds**: For cutrank = number of probes(genes) - Maxseeds
# * **total_background_num**: Number of background runs for global background refrence statistics
# * **n_cores**: Number of machine cores

# %%
Frac_Var = 0.85 
DFrac_Var = 0.03 
N_trials =20  
MaxSeeds = 10000
total_background_num=20
n_cores=5
# Out:
# 5

# %% [markdown]
# ## Subset datasets and set seeds

# %%
# Extract gene expression
expr = data[2:end, 4:end]
expr = Array{Float64}(expr) 

# Extract gene symbols of gene expression matrix
expr_symbol = data[2:end, 2]

# The number of probes(nprobes) can be used as the total genes input in CYCLOPS
# Because the script was written for microarray data at the first time
nprobes=size(expr)[1]
cutrank=nprobes-MaxSeeds
seed_MinMean=(sort(vec(mean(expr,2))))[cutrank] #mean of dim=2 (mean of rows/genes)

# Reseed the random number generator
srand(123456)
# Out:
# MersenneTwister(UInt32[0x0001e240], Base.dSFMT.DSFMT_state(Int32[-1659974861, 1073470649, 358281436, 1073351076, -836744907, 1073086183, 1497051007, 1072821109, 960204239, 1073516083  …  -761652241, 1073037584, -1988158346, 1073300352, -1977759271, 1347447899, 1840933752, -1237490475, 382, 0]), [1.07189, 1.87502, 1.43586, 1.22449, 1.43677, 1.48514, 1.73852, 1.93363, 1.80625, 1.07452  …  1.23687, 1.88544, 1.67686, 1.97169, 1.10156, 1.98025, 1.00876, 1.10863, 1.78681, 1.48881], 382)

# %%
# Get gene symbol and expression data from seed genes
seed_symbol, seed_data = getseed(data,seed_list,.7,.14,seed_MinMean,.975)
seed_data_dispersion = dispersion!(seed_data)
outs, norm_seed_data = GetEigenGenes(seed_data_dispersion,Frac_Var,DFrac_Var,30)
# Out:
# (4, [-0.800641 -0.244913 … 0.0834842 1.20215; -0.0428944 -0.803919 … -0.0157068 -0.327027; -0.621947 -0.179344 … -0.454956 -0.290892; -0.713671 -0.13613 … 0.0843836 -0.38758])

# %% [markdown]
# ## CYCLOPS ordering

# %%
# Predict estimated phases
estimated_phaselist,bestnet,global_var_metrics=CYCLOPS_Order_multicore(outs,norm_seed_data,N_trials)

# Smoothing
global_smooth_metrics = smoothness_measures(seed_data_dispersion, norm_seed_data, estimated_phaselist)
pvals = multicore_backgroundstatistics_global_eigen(seed_data_dispersion, outs, N_trials, total_background_num, global_var_metrics)
# Out:
# 	From worker 6:	15000 of max 15000 stochastic epochs
# 	From worker 2:	15000 of max 15000 stochastic epochs
# 	From worker 4:	15000 of max 15000 stochastic epochs
# WARNING: uuid4(rng) is deprecated, use Compat.UUIDs.uuid4(rng) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] uuid4(::MersenneTwister) at ./deprecated.jl:57
#  [3] msg_header at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:18 [inlined]
#  [4] msg_pub(::IJulia.Msg, ::String, ::Dict{String,String}, ::Dict{String,Any}) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:30 (repeats 2 times)
#  [5] send_stream(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:172
#  [6] send_stdio(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:130
#  [7] (::Base.##302#303{IJulia.#send_stdout,Timer})() at ./event.jl:436
# while loading In[6], in expression starting on line 2
# 	From worker 3:	15000 of max 15000 stochastic epochs
# 	From worker 5:	15000 of max 15000 stochastic epochs
# 	From worker 6:	290 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	380 of max 5000.0 non-stochastic epochs
# 	From worker 2:	426 of max 5000.0 non-stochastic epochs
# 	From worker 5:	400 of max 5000.0 non-stochastic epochs
# 	From worker 3:	103 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 4:	777 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 6:	0.54024326587232315000 of max 15000 stochastic epochs
# 	From worker 3:	0.540244725473194715000 of max 15000 stochastic epochs
# 	From worker 2:	0.542711040522440715000 of max 15000 stochastic epochs
# 	From worker 5:	0.540241623454913415000 of max 15000 stochastic epochs
# 	From worker 4:	0.542714193096037515000 of max 15000 stochastic epochs
# 	From worker 2:	368 of max 5000.0 non-stochastic epochs
# 	From worker 6:	581 of max 5000.0 non-stochastic epochs
# 	From worker 2:	103 of max 5000 bold epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 3:	489 of max 5000.0 non-stochastic epochs
# 	From worker 3:	102 of max 5000 bold epochs
# 	From worker 5:	592 of max 5000.0 non-stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 4:	554 of max 5000.0 non-stochastic epochs
# 	From worker 4:	107 of max 5000 bold epochs
# 	From worker 6:	0.54398781151615215000 of max 15000 stochastic epochs
# 	From worker 2:	0.543967083352108715000 of max 15000 stochastic epochs
# 	From worker 3:	0.540244485010423915000 of max 15000 stochastic epochs
# 	From worker 2:	205 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	0.542708460350763415000 of max 15000 stochastic epochs
# 	From worker 4:	0.542713444092220715000 of max 15000 stochastic epochs
# 	From worker 3:	478 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	422 of max 5000.0 non-stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 2:	0.542706632378840915000 of max 15000 stochastic epochs
# 	From worker 4:	625 of max 5000.0 non-stochastic epochs
# 	From worker 6:	1222 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	0.542716017605017315000 of max 15000 stochastic epochs
# 	From worker 5:	0.542709468777524215000 of max 15000 stochastic epochs
# 	From worker 4:	0.543993097885417815000 of max 15000 stochastic epochs
# 	From worker 5:	398 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.544003175797519415000 of max 15000 stochastic epochs
# 	From worker 3:	709 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 6:	304 of max 5000.0 non-stochastic epochs
# 	From worker 2:	1278 of max 5000.0 non-stochastic epochs
# 	From worker 6:	102 of max 5000 bold epochs
# 	From worker 2:	103 of max 5000 bold epochs
# 	From worker 4:	578 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 4:	0.540245315688214515000 of max 15000 stochastic epochs
# 	From worker 2:	0.543982469565226215000 of max 15000 stochastic epochs
# 	From worker 5:	0.540249675451206615000 of max 15000 stochastic epochs
# WARNING: uuid4(rng) is deprecated, use Compat.UUIDs.uuid4(rng) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] uuid4(::MersenneTwister) at ./deprecated.jl:57
#  [3] msg_header at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:18 [inlined]
#  [4] msg_pub(::IJulia.Msg, ::String, ::Dict{String,String}, ::Dict{String,Any}) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:30 (repeats 2 times)
#  [5] send_stream(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:172
#  [6] send_stdio(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:130
#  [7] (::Base.##302#303{IJulia.#send_stdout,Timer})() at ./event.jl:436
# while loading In[6], in expression starting on line 6
# 	From worker 3:	0.542714894113619415000 of max 15000 stochastic epochs
# 	From worker 6:	0.540240787912021215000 of max 15000 stochastic epochs
# 	From worker 2:	227 of max 5000.0 non-stochastic epochs
# 	From worker 4:	298 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	773 of max 5000.0 non-stochastic epochs
# 	From worker 6:	784 of max 5000.0 non-stochastic epochs
# 	From worker 3:	807 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.554265294494326315000 of max 15000 stochastic epochs
# 	From worker 4:	0.55655996907875415000 of max 15000 stochastic epochs
# 	From worker 2:	321 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	0.544620015646839715000 of max 15000 stochastic epochs
# 	From worker 4:	475 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.549821667807381215000 of max 15000 stochastic epochs
# 	From worker 3:	0.546002917856895715000 of max 15000 stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 3:	329 of max 5000.0 non-stochastic epochs
# 	From worker 6:	433 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	0.554257328263281415000 of max 15000 stochastic epochs
# 	From worker 5:	839 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.556647370624921915000 of max 15000 stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	0.546007688715626715000 of max 15000 stochastic epochs
# 	From worker 6:	0.549782420212555715000 of max 15000 stochastic epochs
# 	From worker 4:	468 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 5:	0.554609077640102515000 of max 15000 stochastic epochs
# 	From worker 6:	500 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	1203 of max 5000.0 non-stochastic epochs
# 	From worker 3:	724 of max 5000.0 non-stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 5:	530 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.552561326907187315000 of max 15000 stochastic epochs
# 	From worker 5:	101 of max 5000 bold epochs
# 	From worker 4:	371 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.549789501228403515000 of max 15000 stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 2:	0.562067149627290915000 of max 15000 stochastic epochs
# 	From worker 3:	0.546003544230945715000 of max 15000 stochastic epochs
# 	From worker 5:	0.544611484727691315000 of max 15000 stochastic epochs
# 	From worker 3:	440 of max 5000.0 non-stochastic epochs
# 	From worker 2:	521 of max 5000.0 non-stochastic epochs
# 	From worker 6:	733 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 4:	0.549618987317105115000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 5:	564 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	395 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 3:	0.54600333080451515000 of max 15000 stochastic epochs
# 	From worker 2:	0.554266504661148115000 of max 15000 stochastic epochs
# 	From worker 6:	0.556528015387492215000 of max 15000 stochastic epochs
# 	From worker 5:	0.54589639612726715000 of max 15000 stochastic epochs
# 	From worker 2:	341 of max 5000.0 non-stochastic epochs
# 	From worker 6:	350 of max 5000.0 non-stochastic epochs
# 	From worker 3:	426 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	101 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 4:	0.550567708691988515000 of max 15000 stochastic epochs
# 	From worker 5:	565 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 4:	461 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 6:	0.557813950052182215000 of max 15000 stochastic epochs
# 	From worker 2:	0.554260367221974615000 of max 15000 stochastic epochs
# 	From worker 3:	0.543310518431030815000 of max 15000 stochastic epochs
# 	From worker 5:	0.544639028064286215000 of max 15000 stochastic epochs
# 	From worker 3:	391 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 2:	580 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.549821389044045815000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	446 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 6:	944 of max 5000.0 non-stochastic epochs
# 	From worker 6:	102 of max 5000 bold epochs
# 	From worker 4:	504 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 3:	0.543310893060920515000 of max 15000 stochastic epochs
# 	From worker 2:	0.554282731906962915000 of max 15000 stochastic epochs
# 	From worker 5:	0.544612963908411715000 of max 15000 stochastic epochs
# 	From worker 6:	0.554150522902199515000 of max 15000 stochastic epochs
# 	From worker 5:	234 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	629 of max 5000.0 non-stochastic epochs
# 	From worker 6:	166 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.550563252454963815000 of max 15000 stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 6:	102 of max 5000 bold epochs
# 	From worker 4:	287 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	0.544464225739056215000 of max 15000 stochastic epochs
# 	From worker 6:	0.557856181352997315000 of max 15000 stochastic epochs
# 	From worker 3:	0.546005901533716415000 of max 15000 stochastic epochs
# 	From worker 5:	338 of max 5000.0 non-stochastic epochs
# 	From worker 5:	101 of max 5000 bold epochs
# 	From worker 4:	0.549616716510419315000 of max 15000 stochastic epochs
# 	From worker 4:	231 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 2:	1953 of max 5000.0 non-stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 6:	926 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.544616794726949315000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.550559722273157615000 of max 15000 stochastic epochs
# 	From worker 5:	524 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.56208359471775315000 of max 15000 stochastic epochs
# 	From worker 5:	101 of max 5000 bold epochs
# 	From worker 6:	0.549789873417969515000 of max 15000 stochastic epochs
# 	From worker 2:	581 of max 5000.0 non-stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 6:	571 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.544612034733569715000 of max 15000 stochastic epochs
# 	From worker 3:	2370 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 4:	1440 of max 5000.0 non-stochastic epochs
# 	From worker 4:	48 of max 5000 bold epochs
# 	From worker 2:	0.562656531964660915000 of max 15000 stochastic epochs
# 	From worker 5:	825 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.549792939642287815000 of max 15000 stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	0.543313099393503315000 of max 15000 stochastic epochs
# 	From worker 4:	0.554138412750569515000 of max 15000 stochastic epochs
# 	From worker 3:	595 of max 5000.0 non-stochastic epochs
# 	From worker 6:	759 of max 5000.0 non-stochastic epochs
# 	From worker 2:	852 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.554597396494893515000 of max 15000 stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	528 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	0.543308646638362515000 of max 15000 stochastic epochs
# 	From worker 6:	0.556647181013288915000 of max 15000 stochastic epochs
# 	From worker 2:	0.554265814430077615000 of max 15000 stochastic epochs
# 	From worker 5:	938 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.549847348418939115000 of max 15000 stochastic epochs
# 	From worker 3:	569 of max 5000.0 non-stochastic epochs
# 	From worker 2:	525 of max 5000.0 non-stochastic epochs
# 	From worker 6:	590 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 4:	310 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	0.554583718655928815000 of max 15000 stochastic epochs
# 	From worker 5:	320 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 3:	0.543309601833778515000 of max 15000 stochastic epochs
# 	From worker 6:	0.549855713065063515000 of max 15000 stochastic epochs
# 	From worker 2:	0.554262897802291815000 of max 15000 stochastic epochs
# 	From worker 4:	0.556563783681431415000 of max 15000 stochastic epochs
# 	From worker 5:	0.544623411772303315000 of max 15000 stochastic epochs
# 	From worker 2:	743 of max 5000.0 non-stochastic epochs
# 	From worker 6:	788 of max 5000.0 non-stochastic epochs
# 	From worker 6:	102 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	930 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 6:	0.5540585604022915000 of max 15000 stochastic epochs
# 	From worker 4:	1516 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.554276705535854315000 of max 15000 stochastic epochs
# 	From worker 4:	52 of max 5000 bold epochs
# 	From worker 5:	1032 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.546002490326107415000 of max 15000 stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 2:	533 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	780 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.554145529209271615000 of max 15000 stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 5:	0.554581790359073615000 of max 15000 stochastic epochs
# 	From worker 4:	273 of max 5000.0 non-stochastic epochs
# 	From worker 3:	988 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.55426332990848615000 of max 15000 stochastic epochs
# 	From worker 5:	594 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 6:	0.556648991411418115000 of max 15000 stochastic epochs
# 	From worker 4:	0.549620367197190815000 of max 15000 stochastic epochs
# 	From worker 3:	0.546002674825962315000 of max 15000 stochastic epochs
# 	From worker 6:	499 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	783 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.544466234535293215000 of max 15000 stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 3:	553 of max 5000.0 non-stochastic epochs
# 	From worker 3:	38 of max 5000 bold epochs
# 	From worker 6:	0.549774483799206215000 of max 15000 stochastic epochs
# 	From worker 4:	975 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	807 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.554265773918120515000 of max 15000 stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	378 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.54639847243199315000 of max 15000 stochastic epochs
# 	From worker 2:	279 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 4:	0.554161270947132415000 of max 15000 stochastic epochs
# 	From worker 5:	0.554558306854894515000 of max 15000 stochastic epochs
# 	From worker 3:	652 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.549773206349878715000 of max 15000 stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.554262742173490615000 of max 15000 stochastic epochs
# 	From worker 5:	542 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 6:	498 of max 5000.0 non-stochastic epochs
# 	From worker 4:	843 of max 5000.0 non-stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 2:	478 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	0.546006042980448315000 of max 15000 stochastic epochs
# 	From worker 5:	0.54461461090741515000 of max 15000 stochastic epochs
# 	From worker 6:	0.549777743577835315000 of max 15000 stochastic epochs
# 	From worker 4:	0.554146011504246915000 of max 15000 stochastic epochs
# 	From worker 3:	620 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.554267563499047915000 of max 15000 stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 4:	277 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	928 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 2:	634 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 3:	0.543313025699586415000 of max 15000 stochastic epochs
# 	From worker 6:	1050 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.549620987492655315000 of max 15000 stochastic epochs
# 	From worker 3:	285 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	0.554562869776343215000 of max 15000 stochastic epochs
# 	From worker 2:	0.554277245016869515000 of max 15000 stochastic epochs
# 	From worker 4:	599 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.54978956183642715000 of max 15000 stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 5:	577 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.543305122747518315000 of max 15000 stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 2:	525 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	594 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.556590206692146315000 of max 15000 stochastic epochs
# 	From worker 3:	720 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.544626276134796615000 of max 15000 stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.554268743849987915000 of max 15000 stochastic epochs
# 	From worker 6:	0.551152247488746115000 of max 15000 stochastic epochs
# 	From worker 2:	565 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.546006460390021215000 of max 15000 stochastic epochs
# 	From worker 6:	488 of max 5000.0 non-stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 5:	942 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 4:	1239 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 3:	380 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.562035488953229215000 of max 15000 stochastic epochs
# 	From worker 6:	0.549781855822742215000 of max 15000 stochastic epochs
# 	From worker 5:	0.544624029139239115000 of max 15000 stochastic epochs
# 	From worker 4:	0.550571208498769715000 of max 15000 stochastic epochs
# 	From worker 2:	274 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.546002293859111415000 of max 15000 stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 6:	399 of max 5000.0 non-stochastic epochs
# 	From worker 5:	428 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 5:	101 of max 5000 bold epochs
# 	From worker 3:	306 of max 5000.0 non-stochastic epochs
# 	From worker 4:	508 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 2:	0.562036634091579215000 of max 15000 stochastic epochs
# 	From worker 6:	0.553976592834918815000 of max 15000 stochastic epochs
# 	From worker 5:	0.54461144343719315000 of max 15000 stochastic epochs
# 	From worker 3:	0.546002800986332415000 of max 15000 stochastic epochs
# 	From worker 4:	0.554631844266136415000 of max 15000 stochastic epochs
# 	From worker 2:	500 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	681 of max 5000.0 non-stochastic epochs
# 	From worker 3:	482 of max 5000.0 non-stochastic epochs
# 	From worker 5:	715 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 4:	547 of max 5000.0 non-stochastic epochs
# 	From worker 4:	102 of max 5000 bold epochs
# 	From worker 2:	0.55434027322394315000 of max 15000 stochastic epochs
# 	From worker 6:	0.55221370344067815000 of max 15000 stochastic epochs
# 	From worker 5:	0.546235236838660215000 of max 15000 stochastic epochs
# 	From worker 3:	0.543308030754347515000 of max 15000 stochastic epochs
# 	From worker 2:	358 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	0.566602650744436615000 of max 15000 stochastic epochs
# 	From worker 3:	137 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	740 of max 5000.0 non-stochastic epochs
# 	From worker 6:	803 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	108 of max 5000 bold epochs
# 	From worker 4:	724 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.557215461747542815000 of max 15000 stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	0.548320494378846115000 of max 15000 stochastic epochs
# 	From worker 3:	382 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	0.546234425900578715000 of max 15000 stochastic epochs
# 	From worker 6:	0.553638117164289915000 of max 15000 stochastic epochs
# 	From worker 4:	0.561469453659634715000 of max 15000 stochastic epochs
# 	From worker 4:	255 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 5:	564 of max 5000.0 non-stochastic epochs
# 	From worker 2:	1178 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	0.548331195505111615000 of max 15000 stochastic epochs
# 	From worker 6:	890 of max 5000.0 non-stochastic epochs
# 	From worker 3:	284 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 4:	0.561459517043955915000 of max 15000 stochastic epochs
# 	From worker 5:	0.548684220020345215000 of max 15000 stochastic epochs
# 	From worker 2:	0.557234793463474315000 of max 15000 stochastic epochs
# 	From worker 6:	0.552213560339571315000 of max 15000 stochastic epochs
# 	From worker 3:	0.548333525657192715000 of max 15000 stochastic epochs
# 	From worker 4:	665 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	880 of max 5000.0 non-stochastic epochs
# 	From worker 3:	516 of max 5000.0 non-stochastic epochs
# 	From worker 2:	922 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 6:	500 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	108 of max 5000 bold epochs
# 	From worker 4:	0.569250441736306715000 of max 15000 stochastic epochs
# 	From worker 5:	0.548758507782870715000 of max 15000 stochastic epochs
# 	From worker 3:	0.550814878018044915000 of max 15000 stochastic epochs
# 	From worker 6:	0.553620314026112615000 of max 15000 stochastic epochs
# 	From worker 2:	0.557218774982802915000 of max 15000 stochastic epochs
# 	From worker 4:	688 of max 5000.0 non-stochastic epochs
# 	From worker 5:	524 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	550 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 6:	680 of max 5000.0 non-stochastic epochs
# 	From worker 6:	107 of max 5000 bold epochs
# 	From worker 2:	1103 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.56148839645104415000 of max 15000 stochastic epochs
# 	From worker 5:	0.546228752492469215000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	0.548328171014182615000 of max 15000 stochastic epochs
# 	From worker 4:	280 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.550757498429825115000 of max 15000 stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	454 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	795 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.55723131043697615000 of max 15000 stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 4:	0.561457564394411715000 of max 15000 stochastic epochs
# 	From worker 6:	863 of max 5000.0 non-stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 3:	0.548325186764342515000 of max 15000 stochastic epochs
# 	From worker 5:	0.546239014970450415000 of max 15000 stochastic epochs
# 	From worker 2:	945 of max 5000.0 non-stochastic epochs
# 	From worker 4:	739 of max 5000.0 non-stochastic epochs
# 	From worker 5:	279 of max 5000.0 non-stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 3:	499 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	0.550774167408836115000 of max 15000 stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 6:	624 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.561417899142606815000 of max 15000 stochastic epochs
# 	From worker 4:	0.561463812815676915000 of max 15000 stochastic epochs
# 	From worker 5:	0.546228663137424815000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 3:	0.550812821326217815000 of max 15000 stochastic epochs
# 	From worker 5:	509 of max 5000.0 non-stochastic epochs
# 	From worker 2:	545 of max 5000.0 non-stochastic epochs
# 	From worker 5:	107 of max 5000 bold epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 4:	754 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.552201029067298315000 of max 15000 stochastic epochs
# 	From worker 4:	112 of max 5000 bold epochs
# 	From worker 3:	826 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	0.553587421193338915000 of max 15000 stochastic epochs
# 	From worker 6:	548 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.562922245361939215000 of max 15000 stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 4:	0.580520870445606615000 of max 15000 stochastic epochs
# 	From worker 2:	305 of max 5000.0 non-stochastic epochs
# 	From worker 2:	110 of max 5000 bold epochs
# 	From worker 3:	0.548342527686130815000 of max 15000 stochastic epochs
# 	From worker 4:	431 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 6:	0.550760399669639715000 of max 15000 stochastic epochs
# 	From worker 2:	0.56577813847633215000 of max 15000 stochastic epochs
# 	From worker 6:	407 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	280 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.561482943051521815000 of max 15000 stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 4:	286 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	1467 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 6:	0.556437279007033715000 of max 15000 stochastic epochs
# 	From worker 2:	0.557232166947851615000 of max 15000 stochastic epochs
# 	From worker 4:	0.561465024085486615000 of max 15000 stochastic epochs
# 	From worker 3:	0.548468571722800715000 of max 15000 stochastic epochs
# 	From worker 2:	436 of max 5000.0 non-stochastic epochs
# 	From worker 2:	103 of max 5000 bold epochs
# 	From worker 6:	964 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	782 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.565632541332173715000 of max 15000 stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 4:	1108 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 6:	0.552213768175777715000 of max 15000 stochastic epochs
# 	From worker 2:	662 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.548340207403441215000 of max 15000 stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 6:	496 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.561474939117911815000 of max 15000 stochastic epochs
# 	From worker 5:	5000 of max 5000.0 non-stochastic epochs
# 	From worker 4:	242 of max 5000.0 non-stochastic epochs
# 	From worker 5:	98 of max 5000 bold epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 2:	0.562310545113635715000 of max 15000 stochastic epochs
# 	From worker 3:	847 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.55220785900137815000 of max 15000 stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	0.62909063240861615000 of max 15000 stochastic epochs
# 	From worker 4:	0.56145939529744715000 of max 15000 stochastic epochs
# 	From worker 4:	184 of max 5000.0 non-stochastic epochs
# 	From worker 4:	102 of max 5000 bold epochs
# 	From worker 3:	0.548330625301470615000 of max 15000 stochastic epochs
# 	From worker 6:	920 of max 5000.0 non-stochastic epochs
# 	From worker 3:	165 of max 5000.0 non-stochastic epochs
# 	From worker 2:	1088 of max 5000.0 non-stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	828 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.562130835394723615000 of max 15000 stochastic epochs
# 	From worker 6:	0.550769480087987115000 of max 15000 stochastic epochs
# 	From worker 3:	0.548328053711679715000 of max 15000 stochastic epochs
# 	From worker 2:	0.557217572515987515000 of max 15000 stochastic epochs
# 	From worker 5:	0.546234660510368215000 of max 15000 stochastic epochs
# 	From worker 6:	396 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	676 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	749 of max 5000.0 non-stochastic epochs
# 	From worker 5:	102 of max 5000 bold epochs
# 	From worker 2:	1027 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.55644190955737615000 of max 15000 stochastic epochs
# 	From worker 2:	108 of max 5000 bold epochs
# 	From worker 4:	1682 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	0.550819553066416315000 of max 15000 stochastic epochs
# 	From worker 5:	0.548768816679693115000 of max 15000 stochastic epochs
# 	From worker 3:	245 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 6:	696 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.561360070009006615000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.561478646704184515000 of max 15000 stochastic epochs
# 	From worker 5:	690 of max 5000.0 non-stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 3:	0.55081044970030815000 of max 15000 stochastic epochs
# 	From worker 2:	703 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.556436054974362315000 of max 15000 stochastic epochs
# 	From worker 2:	110 of max 5000 bold epochs
# 	From worker 6:	422 of max 5000.0 non-stochastic epochs
# 	From worker 4:	966 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.546229903274395215000 of max 15000 stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 3:	797 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 2:	0.565774398285075515000 of max 15000 stochastic epochs
# 	From worker 6:	0.556432571814603515000 of max 15000 stochastic epochs
# 	From worker 4:	0.56147496799018515000 of max 15000 stochastic epochs
# 	From worker 3:	0.550816542094027615000 of max 15000 stochastic epochs
# 	From worker 2:	1060 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 6:	872 of max 5000.0 non-stochastic epochs
# 	From worker 3:	600 of max 5000.0 non-stochastic epochs
# 	From worker 6:	107 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 4:	1136 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 2:	0.557259864864752915000 of max 15000 stochastic epochs
# 	From worker 6:	0.55077203185290715000 of max 15000 stochastic epochs
# 	From worker 3:	0.559205854061075115000 of max 15000 stochastic epochs
# 	From worker 4:	0.561481323282612515000 of max 15000 stochastic epochs
# 	From worker 2:	630 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 4:	386 of max 5000.0 non-stochastic epochs
# 	From worker 6:	778 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 2:	0.557221653481952315000 of max 15000 stochastic epochs
# 	From worker 4:	0.561476216707774615000 of max 15000 stochastic epochs
# 	From worker 6:	0.550767865443067815000 of max 15000 stochastic epochs
# 	From worker 3:	1682 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 2:	548 of max 5000.0 non-stochastic epochs
# 	From worker 2:	110 of max 5000 bold epochs
# 	From worker 6:	596 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 5:	5000 of max 5000.0 non-stochastic epochs
# 	From worker 5:	107 of max 5000 bold epochs
# 	From worker 3:	0.550817824546544815000 of max 15000 stochastic epochs
# 	From worker 3:	135 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.565770349854791615000 of max 15000 stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 4:	1393 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.556437269953571815000 of max 15000 stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 5:	0.574867208995959715000 of max 15000 stochastic epochs
# 	From worker 2:	666 of max 5000.0 non-stochastic epochs
# 	From worker 2:	103 of max 5000 bold epochs
# 	From worker 3:	0.550808883220093515000 of max 15000 stochastic epochs
# 	From worker 5:	529 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.561474465501662915000 of max 15000 stochastic epochs
# 	From worker 2:	0.562308391846827215000 of max 15000 stochastic epochs
# 	From worker 4:	542 of max 5000.0 non-stochastic epochs
# 	From worker 6:	1428 of max 5000.0 non-stochastic epochs
# 	From worker 4:	111 of max 5000 bold epochs
# 	From worker 3:	927 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.548679571916695915000 of max 15000 stochastic epochs
# 	From worker 6:	107 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 2:	675 of max 5000.0 non-stochastic epochs
# 	From worker 2:	109 of max 5000 bold epochs
# 	From worker 5:	634 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.580488712529235315000 of max 15000 stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 6:	0.558367252795884115000 of max 15000 stochastic epochs
# 	From worker 3:	0.550824737990589715000 of max 15000 stochastic epochs
# 	From worker 4:	393 of max 5000.0 non-stochastic epochs
# 	From worker 6:	368 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 2:	0.565770920346013215000 of max 15000 stochastic epochs
# 	From worker 5:	0.546232393033214515000 of max 15000 stochastic epochs
# 	From worker 3:	942 of max 5000.0 non-stochastic epochs
# 	From worker 5:	305 of max 5000.0 non-stochastic epochs
# 	From worker 3:	110 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	0.550764081258891415000 of max 15000 stochastic epochs
# 	From worker 4:	0.561477693664369715000 of max 15000 stochastic epochs
# 	From worker 4:	278 of max 5000.0 non-stochastic epochs
# 	From worker 6:	370 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 6:	107 of max 5000 bold epochs
# 	From worker 3:	0.561319970390280815000 of max 15000 stochastic epochs
# 	From worker 5:	0.546225029018665315000 of max 15000 stochastic epochs
# 	From worker 2:	1398 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 4:	0.553958509627884415000 of max 15000 stochastic epochs
# 	From worker 6:	0.560125667598722115000 of max 15000 stochastic epochs
# 	From worker 3:	590 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	843 of max 5000.0 non-stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 2:	0.562916945986378215000 of max 15000 stochastic epochs
# 	From worker 6:	520 of max 5000.0 non-stochastic epochs
# 	From worker 6:	107 of max 5000 bold epochs
# 	From worker 2:	358 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.538928347571995915000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	0.546228762034674915000 of max 15000 stochastic epochs
# 	From worker 4:	1383 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.573485273235015715000 of max 15000 stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 3:	673 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.557223002574648415000 of max 15000 stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 6:	475 of max 5000.0 non-stochastic epochs
# 	From worker 5:	784 of max 5000.0 non-stochastic epochs
# 	From worker 6:	108 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.554005199802296615000 of max 15000 stochastic epochs
# 	From worker 3:	0.538930154564839415000 of max 15000 stochastic epochs
# 	From worker 4:	343 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.56008296278641315000 of max 15000 stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	0.5462267184660115000 of max 15000 stochastic epochs
# 	From worker 2:	1079 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	732 of max 5000.0 non-stochastic epochs
# 	From worker 6:	546 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	604 of max 5000.0 non-stochastic epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.551247980743771915000 of max 15000 stochastic epochs
# 	From worker 2:	0.54096650779338115000 of max 15000 stochastic epochs
# 	From worker 3:	0.538932956777430915000 of max 15000 stochastic epochs
# 	From worker 6:	0.563903647724497415000 of max 15000 stochastic epochs
# 	From worker 5:	0.546229119682648915000 of max 15000 stochastic epochs
# 	From worker 2:	438 of max 5000.0 non-stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 6:	264 of max 5000.0 non-stochastic epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 4:	1060 of max 5000.0 non-stochastic epochs
# 	From worker 5:	518 of max 5000.0 non-stochastic epochs
# 	From worker 4:	102 of max 5000 bold epochs
# 	From worker 3:	625 of max 5000.0 non-stochastic epochs
# 	From worker 5:	108 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 2:	0.540913101719214915000 of max 15000 stochastic epochs
# 	From worker 6:	0.566489078310932915000 of max 15000 stochastic epochs
# 	From worker 4:	0.557614878669027415000 of max 15000 stochastic epochs
# 	From worker 5:	0.553589513370069615000 of max 15000 stochastic epochs
# 	From worker 3:	0.53893086482657915000 of max 15000 stochastic epochs
# 	From worker 2:	670 of max 5000.0 non-stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 3:	403 of max 5000.0 non-stochastic epochs
# 	From worker 5:	491 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 6:	1143 of max 5000.0 non-stochastic epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 2:	0.540947238801071215000 of max 15000 stochastic epochs
# 	From worker 3:	0.538925844665561315000 of max 15000 stochastic epochs
# 	From worker 5:	0.548263173159078415000 of max 15000 stochastic epochs
# 	From worker 2:	389 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	0.566501858301145315000 of max 15000 stochastic epochs
# 	From worker 4:	1805 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	639 of max 5000.0 non-stochastic epochs
# 	From worker 5:	111 of max 5000 bold epochs
# 	From worker 3:	828 of max 5000.0 non-stochastic epochs
# 	From worker 6:	522 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 2:	0.540937702756212215000 of max 15000 stochastic epochs
# 	From worker 4:	0.551250013201759715000 of max 15000 stochastic epochs
# 	From worker 5:	0.558998477235522715000 of max 15000 stochastic epochs
# 	From worker 2:	493 of max 5000.0 non-stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 3:	0.538935198290311615000 of max 15000 stochastic epochs
# 	From worker 4:	487 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.563901792461737215000 of max 15000 stochastic epochs
# 	From worker 4:	107 of max 5000 bold epochs
# 	From worker 5:	449 of max 5000.0 non-stochastic epochs
# 	From worker 6:	183 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 2:	0.543738467004319215000 of max 15000 stochastic epochs
# 	From worker 3:	821 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.551259020589139915000 of max 15000 stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 5:	0.54826056750964915000 of max 15000 stochastic epochs
# 	From worker 2:	380 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.573477906287518615000 of max 15000 stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 5:	400 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	0.53893167186927515000 of max 15000 stochastic epochs
# 	From worker 4:	890 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 2:	0.540914518539258515000 of max 15000 stochastic epochs
# 	From worker 6:	874 of max 5000.0 non-stochastic epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 2:	198 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.548259309085719815000 of max 15000 stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 3:	599 of max 5000.0 non-stochastic epochs
# 	From worker 3:	103 of max 5000 bold epochs
# 	From worker 5:	228 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.554026420881257615000 of max 15000 stochastic epochs
# 	From worker 6:	0.563902488689721915000 of max 15000 stochastic epochs
# 	From worker 2:	0.543742749303016415000 of max 15000 stochastic epochs
# 	From worker 3:	0.538927643015427315000 of max 15000 stochastic epochs
# 	From worker 6:	344 of max 5000.0 non-stochastic epochs
# 	From worker 5:	0.548258713395232515000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	351 of max 5000.0 non-stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 5:	316 of max 5000.0 non-stochastic epochs
# 	From worker 5:	105 of max 5000 bold epochs
# 	From worker 3:	526 of max 5000.0 non-stochastic epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 6:	0.573870400208107515000 of max 15000 stochastic epochs
# 	From worker 4:	1594 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.540917563559023415000 of max 15000 stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	0.548260020598293515000 of max 15000 stochastic epochs
# 	From worker 3:	0.538932175801298515000 of max 15000 stochastic epochs
# 	From worker 2:	668 of max 5000.0 non-stochastic epochs
# 	From worker 6:	969 of max 5000.0 non-stochastic epochs
# 	From worker 5:	668 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.55759577578849415000 of max 15000 stochastic epochs
# 	From worker 2:	104 of max 5000 bold epochs
# 	From worker 6:	110 of max 5000 bold epochs
# 	From worker 3:	574 of max 5000.0 non-stochastic epochs
# 	From worker 5:	111 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 4:	451 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	0.559013095051657315000 of max 15000 stochastic epochs
# 	From worker 6:	0.566506392225173815000 of max 15000 stochastic epochs
# 	From worker 2:	0.540927407699922315000 of max 15000 stochastic epochs
# 	From worker 6:	106 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.538933973809869515000 of max 15000 stochastic epochs
# 	From worker 6:	111 of max 5000 bold epochs
# 	From worker 2:	272 of max 5000.0 non-stochastic epochs
# 	From worker 5:	423 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	111 of max 5000 bold epochs
# 	From worker 4:	0.551992338528742415000 of max 15000 stochastic epochs
# 	From worker 3:	505 of max 5000.0 non-stochastic epochs
# 	From worker 3:	103 of max 5000 bold epochs
# 	From worker 6:	0.565096679227906515000 of max 15000 stochastic epochs
# 	From worker 2:	0.540924355028462915000 of max 15000 stochastic epochs
# 	From worker 5:	0.559002698923332315000 of max 15000 stochastic epochs
# 	From worker 3:	0.538927842430560615000 of max 15000 stochastic epochs
# 	From worker 6:	701 of max 5000.0 non-stochastic epochs
# 	From worker 6:	110 of max 5000 bold epochs
# ...
# 	From worker 2:	648 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 5:	0.556510883900386715000 of max 15000 stochastic epochs
# 	From worker 4:	0.554017507049479315000 of max 15000 stochastic epochs
# 	From worker 3:	0.565766948193474615000 of max 15000 stochastic epochs
# 	From worker 5:	506 of max 5000.0 non-stochastic epochs
# 	From worker 6:	1015 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	483 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.556082620945422915000 of max 15000 stochastic epochs
# 	From worker 3:	103 of max 5000 bold epochs
# 	From worker 5:	0.544040225704767215000 of max 15000 stochastic epochs
# 	From worker 6:	0.555829094562040115000 of max 15000 stochastic epochs
# 	From worker 2:	666 of max 5000.0 non-stochastic epochs
# 	From worker 4:	1312 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.565275026495266115000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 6:	342 of max 5000.0 non-stochastic epochs
# 	From worker 6:	102 of max 5000 bold epochs
# 	From worker 5:	621 of max 5000.0 non-stochastic epochs
# 	From worker 3:	456 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	104 of max 5000 bold epochs
# 	From worker 2:	0.557417575367770915000 of max 15000 stochastic epochs
# 	From worker 4:	0.558558918625893915000 of max 15000 stochastic epochs
# 	From worker 6:	0.550134195634366715000 of max 15000 stochastic epochs
# 	From worker 5:	0.544277022167694215000 of max 15000 stochastic epochs
# 	From worker 3:	0.56528260297188815000 of max 15000 stochastic epochs
# 	From worker 4:	640 of max 5000.0 non-stochastic epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 6:	589 of max 5000.0 non-stochastic epochs
# 	From worker 5:	487 of max 5000.0 non-stochastic epochs
# 	From worker 3:	343 of max 5000.0 non-stochastic epochs
# 	From worker 2:	892 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	101 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	0.55867660244154915000 of max 15000 stochastic epochs
# 	From worker 6:	0.559226318928741115000 of max 15000 stochastic epochs
# 	From worker 5:	0.544274695493657415000 of max 15000 stochastic epochs
# 	From worker 3:	0.552121563933989815000 of max 15000 stochastic epochs
# 	From worker 4:	224 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.55740564396308515000 of max 15000 stochastic epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 5:	248 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	417 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 4:	0.558655074747698715000 of max 15000 stochastic epochs
# 	From worker 2:	810 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	0.54427269367569815000 of max 15000 stochastic epochs
# 	From worker 3:	0.553311908650179415000 of max 15000 stochastic epochs
# 	From worker 4:	630 of max 5000.0 non-stochastic epochs
# 	From worker 4:	105 of max 5000 bold epochs
# 	From worker 5:	757 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.55609014904421115000 of max 15000 stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	614 of max 5000.0 non-stochastic epochs
# 	From worker 3:	101 of max 5000 bold epochs
# 	From worker 4:	0.555411678630762615000 of max 15000 stochastic epochs
# 	From worker 5:	0.544279155151616415000 of max 15000 stochastic epochs
# 	From worker 4:	377 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.552131973285016715000 of max 15000 stochastic epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 5:	419 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	430 of max 5000.0 non-stochastic epochs
# 	From worker 3:	101 of max 5000 bold epochs
# 	From worker 4:	0.558689921667855915000 of max 15000 stochastic epochs
# 	From worker 5:	0.544034996560889915000 of max 15000 stochastic epochs
# 	From worker 3:	0.552123722355843315000 of max 15000 stochastic epochs
# 	From worker 5:	376 of max 5000.0 non-stochastic epochs
# 	From worker 4:	539 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 3:	322 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 5:	0.544278167845773415000 of max 15000 stochastic epochs
# 	From worker 6:	5000 of max 5000.0 non-stochastic epochs
# 	From worker 4:	0.55856025744469615000 of max 15000 stochastic epochs
# 	From worker 6:	53 of max 5000 bold epochs
# 	From worker 3:	0.553317793337399915000 of max 15000 stochastic epochs
# 	From worker 3:	210 of max 5000.0 non-stochastic epochs
# 	From worker 5:	584 of max 5000.0 non-stochastic epochs
# 	From worker 4:	521 of max 5000.0 non-stochastic epochs
# 	From worker 3:	103 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 6:	0.549794458179024515000 of max 15000 stochastic epochs
# 	From worker 5:	0.544278111114932115000 of max 15000 stochastic epochs
# 	From worker 3:	0.552132071343651415000 of max 15000 stochastic epochs
# 	From worker 4:	0.558659677345641315000 of max 15000 stochastic epochs
# 	From worker 3:	441 of max 5000.0 non-stochastic epochs
# 	From worker 5:	561 of max 5000.0 non-stochastic epochs
# 	From worker 3:	101 of max 5000 bold epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 2:	5000 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 3:	0.552122991669370515000 of max 15000 stochastic epochs
# 	From worker 5:	0.544035399796106315000 of max 15000 stochastic epochs
# 	From worker 4:	1261 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	243 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.558316861986479315000 of max 15000 stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 3:	434 of max 5000.0 non-stochastic epochs
# 	From worker 3:	102 of max 5000 bold epochs
# 	From worker 2:	320 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	0.557190703029184615000 of max 15000 stochastic epochs
# 	From worker 5:	0.544282240686077315000 of max 15000 stochastic epochs
# 	From worker 3:	0.552124216189893915000 of max 15000 stochastic epochs
# 	From worker 2:	0.556079477021854915000 of max 15000 stochastic epochs
# 	From worker 5:	457 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 2:	428 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	0.54427793433752915000 of max 15000 stochastic epochs
# 	From worker 3:	1387 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 2:	0.556100785845811715000 of max 15000 stochastic epochs
# 	From worker 4:	2172 of max 5000.0 non-stochastic epochs
# 	From worker 6:	5000 of max 5000.0 non-stochastic epochs
# 	From worker 5:	863 of max 5000.0 non-stochastic epochs
# 	From worker 6:	40 of max 5000 bold epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 5:	107 of max 5000 bold epochs
# 	From worker 2:	656 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.553316439628729915000 of max 15000 stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	0.549783991447326115000 of max 15000 stochastic epochs
# 	From worker 5:	0.55163931601277115000 of max 15000 stochastic epochs
# 	From worker 4:	0.558676514853883815000 of max 15000 stochastic epochs
# 	From worker 3:	711 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.557032055454569615000 of max 15000 stochastic epochs
# 	From worker 3:	102 of max 5000 bold epochs
# 	From worker 5:	465 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 4:	607 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 6:	843 of max 5000.0 non-stochastic epochs
# 	From worker 2:	439 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	0.552133341724128415000 of max 15000 stochastic epochs
# 	From worker 5:	0.556507564596302815000 of max 15000 stochastic epochs
# 	From worker 4:	0.55718777871482815000 of max 15000 stochastic epochs
# 	From worker 6:	0.5486393536928515000 of max 15000 stochastic epochs
# 	From worker 2:	0.55740412918818515000 of max 15000 stochastic epochs
# 	From worker 6:	151 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 2:	245 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	617 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 5:	1137 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	1406 of max 5000.0 non-stochastic epochs
# 	From worker 3:	102 of max 5000 bold epochs
# 	From worker 6:	0.566785413484041315000 of max 15000 stochastic epochs
# 	From worker 2:	0.556080053488592715000 of max 15000 stochastic epochs
# 	From worker 4:	0.558520688768520215000 of max 15000 stochastic epochs
# 	From worker 5:	0.544283865680969415000 of max 15000 stochastic epochs
# 	From worker 6:	705 of max 5000.0 non-stochastic epochs
# 	From worker 5:	279 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.552154139198371115000 of max 15000 stochastic epochs
# 	From worker 6:	101 of max 5000 bold epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 2:	666 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	0.555669737675594815000 of max 15000 stochastic epochs
# 	From worker 5:	0.556508559671047315000 of max 15000 stochastic epochs
# 	From worker 2:	0.556095998791758215000 of max 15000 stochastic epochs
# 	From worker 6:	289 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 4:	1938 of max 5000.0 non-stochastic epochs
# 	From worker 2:	515 of max 5000.0 non-stochastic epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 3:	1629 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 6:	0.555520586166164715000 of max 15000 stochastic epochs
# 	From worker 5:	1319 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 4:	0.558679123124135915000 of max 15000 stochastic epochs
# 	From worker 2:	0.557391871297022815000 of max 15000 stochastic epochs
# 	From worker 3:	0.553316364960075415000 of max 15000 stochastic epochs
# 	From worker 6:	747 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 5:	0.544046179491858215000 of max 15000 stochastic epochs
# 	From worker 2:	735 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 5:	518 of max 5000.0 non-stochastic epochs
# 	From worker 3:	943 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 4:	1150 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.548631187447807715000 of max 15000 stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 2:	0.556095060371087515000 of max 15000 stochastic epochs
# 	From worker 5:	0.544276904998062915000 of max 15000 stochastic epochs
# 	From worker 6:	705 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.553322697820534115000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 4:	0.558686451792911415000 of max 15000 stochastic epochs
# 	From worker 4:	149 of max 5000.0 non-stochastic epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 5:	460 of max 5000.0 non-stochastic epochs
# 	From worker 3:	347 of max 5000.0 non-stochastic epochs
# 	From worker 5:	104 of max 5000 bold epochs
# 	From worker 3:	101 of max 5000 bold epochs
# 	From worker 2:	789 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 6:	0.548643313166908415000 of max 15000 stochastic epochs
# 	From worker 4:	0.558674391449413615000 of max 15000 stochastic epochs
# 	From worker 5:	0.566930693030612915000 of max 15000 stochastic epochs
# 	From worker 6:	338 of max 5000.0 non-stochastic epochs
# 	From worker 3:	0.552123107874722515000 of max 15000 stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	0.556089169056409115000 of max 15000 stochastic epochs
# 	From worker 4:	491 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 2:	300 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 6:	0.54864375285750415000 of max 15000 stochastic epochs
# 	From worker 3:	843 of max 5000.0 non-stochastic epochs
# 	From worker 3:	105 of max 5000 bold epochs
# 	From worker 5:	1097 of max 5000.0 non-stochastic epochs
# 	From worker 5:	103 of max 5000 bold epochs
# 	From worker 4:	0.555406927367165115000 of max 15000 stochastic epochs
# 	From worker 6:	564 of max 5000.0 non-stochastic epochs
# 	From worker 2:	0.557393606415278915000 of max 15000 stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 3:	0.553316314382758915000 of max 15000 stochastic epochs
# 	From worker 4:	559 of max 5000.0 non-stochastic epochs
# 	From worker 2:	349 of max 5000.0 non-stochastic epochs
# 	From worker 4:	103 of max 5000 bold epochs
# 	From worker 2:	103 of max 5000 bold epochs
# 	From worker 6:	0.559824422026167115000 of max 15000 stochastic epochs
# 	From worker 4:	0.557531143273204315000 of max 15000 stochastic epochs
# 	From worker 2:	0.563360963602968715000 of max 15000 stochastic epochs
# 	From worker 2:	204 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	546 of max 5000.0 non-stochastic epochs
# 	From worker 4:	102 of max 5000 bold epochs
# 	From worker 6:	1123 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 	From worker 2:	0.55607714295429615000 of max 15000 stochastic epochs
# 	From worker 4:	0.55948109971007215000 of max 15000 stochastic epochs
# 	From worker 2:	460 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.548639376482806615000 of max 15000 stochastic epochs
# 	From worker 3:	2384 of max 5000.0 non-stochastic epochs
# 	From worker 2:	107 of max 5000 bold epochs
# 	From worker 4:	331 of max 5000.0 non-stochastic epochs
# 	From worker 3:	107 of max 5000 bold epochs
# 	From worker 4:	101 of max 5000 bold epochs
# 	From worker 6:	714 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 2:	0.556102696624346615000 of max 15000 stochastic epochs
# 	From worker 4:	0.558677900370958215000 of max 15000 stochastic epochs
# 	From worker 4:	437 of max 5000.0 non-stochastic epochs
# 	From worker 4:	104 of max 5000 bold epochs
# 	From worker 6:	0.550139777384518415000 of max 15000 stochastic epochs
# 	From worker 2:	727 of max 5000.0 non-stochastic epochs
# 	From worker 2:	105 of max 5000 bold epochs
# 	From worker 4:	0.555410848626448515000 of max 15000 stochastic epochs
# 	From worker 6:	848 of max 5000.0 non-stochastic epochs
# 	From worker 6:	103 of max 5000 bold epochs
# 	From worker 4:	1015 of max 5000.0 non-stochastic epochs
# 	From worker 6:	0.550146017306847515000 of max 15000 stochastic epochs
# 	From worker 4:	102 of max 5000 bold epochs
# 	From worker 6:	1007 of max 5000.0 non-stochastic epochs
# 	From worker 6:	105 of max 5000 bold epochs
# 	From worker 6:	0.548636086743859315000 of max 15000 stochastic epochs
# 	From worker 6:	286 of max 5000.0 non-stochastic epochs
# 	From worker 6:	104 of max 5000 bold epochs
# 3-element Array{Float64,1}:
#  0.05
#  0.05
#  0.05

# %% [markdown]
# ## Cosinor statistics
# **cosinor table:**
#
# 1.  ""
# 2. "Description" (Gene Symbol)
# 3. "Name"       (Gene ID)
# 4. "pval"
# 5. "bon_pval"
# 6. "phase"
# 7. "amp"
# 8. "fitmean"
# 9. "mean"
# 10. "rsq"
# 11. "ptr"

# %%
# Import Filter_cosinor_Output function for filtering bon_pval, ptr, rsq in the cosinor result
function Filter_Cosinor_Output(cosdata::Array{Any,2},pval,ptr,rsq) 
    significant_data=cosdata[append!([1],1 + findin(cosdata[2:end,5] .< pval,true)),:];
    phys_sig_data=significant_data[append!([1],1 + findin(significant_data[2:end,11] .> ptr,true)),:];
    strong_data=phys_sig_data[append!([1],1 + findin(phys_sig_data[2:end,10].> rsq,true)),:];
    strong_data
end
# Out:
# Filter_Cosinor_Output (generic function with 1 method)

# %%
estimated_phaselist = mod.(estimated_phaselist, 2*pi)
cosinor = Compile_MultiCore_Cosinor_Statistics(data, estimated_phaselist, 4, 24)
# Filter bon_pval<0.05, ptr>1.66, rsq>0
sig_cosinor = Filter_Cosinor_Output(cosinor, 0.05, 1.66, 0)
# Out:
# elapsed time: 2.770954719 seconds
# WARNING: uuid4(rng) is deprecated, use Compat.UUIDs.uuid4(rng) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] uuid4(::MersenneTwister) at ./deprecated.jl:57
#  [3] msg_header at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:18 [inlined]
#  [4] msg_pub(::IJulia.Msg, ::String, ::Dict{String,String}, ::Dict{String,Any}) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/msg.jl:30 (repeats 2 times)
#  [5] send_stream(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:172
#  [6] send_stdio(::String) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/stdio.jl:130
#  [7] (::Base.##302#303{IJulia.#send_stdout,Timer})() at ./event.jl:436
# while loading In[8], in expression starting on line 2
# 2425×11 Array{Any,2}:
#       ""  "Description"    …       "mean"    "rsq"       "ptr"
#    104    "RP4-758J18.13"         4.54284   0.246572    1.9623
#    109    "VWA1"                 16.3147    0.471027    5.36103
#    110    "ATAD3C"                2.21003   0.31268     5.25267
#    148    "RER1"                 25.267     0.257224    1.90201
#    229    "KLHL21"         …     20.3781    0.290149    2.03719
#    245    "VAMP3"                43.3568    0.395287    2.97486
#    287    "GPR157"                0.480872  0.269076    2.51473
#    291    "H6PD"                  5.71485   0.325307    2.2516
#    292    "SPSB1"                 4.92211   0.367226    4.70519
#    312    "RBP7"           …      5.74945   0.325993   11.6139
#    324    "DFFA"                 11.9241    0.258403    1.69278
#    327    "CASZ1"                 0.522162  0.439353    4.28908
#      ⋮                     ⋱                            ⋮
#  55501    "SRPK3"                 2.6826    0.275488    2.28275
#  55511    "RENBP"                 8.54283   0.360241    2.94352
#  55528    "FLNA"           …     27.5654    0.419087    3.78439
#  55531    "RPL10"               435.816     0.415115    2.05397
#  55532    "SNORA70"              18.7465    0.381537    2.68312
#  55540    "PLXNA3"                5.99009   0.349544    2.65337
#  55580    "CLIC2"                 4.39634   0.400816    3.02502
#  56165    "MT-TV"          …     45.1551    0.0982682   5.73233
#  56181    "MT-CO2"            63155.5       0.32446     2.04245
#  56183    "MT-ATP8"           26514.0       0.250218    2.11595
#  56184    "MT-ATP6"           51824.3       0.247638    1.81295
#  56185    "MT-CO3"            53802.6       0.288801    2.07894

# %% [markdown]
# ## Align all genes with Ebox(Par-BZip) phase
# Ebox genes: DBP, HLF, TEF
#
# According to Dr. Anafi, Ebox genes in mouse lung peak on average at CT 11.5

# %%
eboxgenes = ["DBP", "HLF", "TEF"]
eboxcosinor = cosinor[findin(cosinor[:,2], eboxgenes), :]

# Criteria(? not sure what is it for
# 4=pval,  9=mean, 11=ptr
# Unable to meet the original mean cutoff(100)
# Because the code is designed for microarray datasets, the mean of expression value are belongs to array expression values
# However, here we are try to analyse GTEx gene expression profile which expression values are TPM, so mean is set to 10 
criteria = ((eboxcosinor[:,4].<0.05) &(eboxcosinor[:,9].>10) & (eboxcosinor[:,11].>1.25)) 
eboxcosinor_fit = eboxcosinor[findin(criteria, true), :]

# Extract phases of Ebox genes
eboxphases = Array{Float64}(eboxcosinor[:,6])
eboxphases_mean = Circular_Mean(eboxphases)
estimated_phaselist_adj = mod.(estimated_phaselist .- eboxphases_mean + (pi), 2*pi)

# Count the number of genes which phase>pi or phase<pi
Nday=length(findin((estimated_phaselist_adj .>pi), true))
Nnight=length(findin((estimated_phaselist_adj .<pi), true))

# Adjust the numebr of the genes belongs to day and night if the number of night gene > the number of day gene
# e.g. 3/2*pi goes to 1/2*pi
if (Nday < Nnight)
    estimated_phaselist_adj = mod.(2*pi - estimated_phaselist_adj, 2*pi)
end
# Out:
# WARNING: A::AbstractArray & B::AbstractArray is deprecated, use A .& B instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] &(::BitArray{1}, ::BitArray{1}) at ./deprecated.jl:57
#  [3] include_string(::String, ::String) at ./loading.jl:522
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/execute_request.jl:193
#  [5] (::Compat.#inner#6{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/pinjouwu9325/.julia/v0.6/Compat/src/Compat.jl:125
#  [6] eventloop(::ZMQ.Socket) at /home/pinjouwu9325/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [7] (::IJulia.##13#16)() at ./task.jl:335
# while loading In[9], in expression starting on line 9
# 209-element Array{Float64,1}:
#  3.33116
#  4.15945
#  4.51455
#  2.90547
#  3.97175
#  4.57336
#  5.16575
#  5.3195
#  3.84143
#  5.12178
#  0.277824
#  4.72683
#  3.4782
#  ⋮
#  4.09661
#  4.1171
#  4.03326
#  5.24188
#  5.28082
#  5.77903
#  2.93383
#  4.3755
#  4.45068
#  4.43172
#  4.27222
#  4.13033

# %% [markdown]
# ## Cosinor statistics after Ebox phase alignment
# The input has changed to the adjusted phase after Ebox alignment

# %%
cosinor_adj = Compile_MultiCore_Cosinor_Statistics(data, estimated_phaselist_adj, 4, 24)
# Filter bon_pval<0.05, ptr>1.66, rsq>0
sig_cosinor_adj = Filter_Cosinor_Output(cosinor_adj, 0.05, 1.66, 0)
# Out:
# elapsed time: 1.612446978 seconds
# 2417×11 Array{Any,2}:
#       ""  "Description"    …       "mean"    "rsq"       "ptr"
#    104    "RP4-758J18.13"         4.54284   0.246572    1.9623
#    109    "VWA1"                 16.3147    0.471027    5.36103
#    110    "ATAD3C"                2.21003   0.31268     5.25267
#    148    "RER1"                 25.267     0.257224    1.90201
#    229    "KLHL21"         …     20.3781    0.290149    2.03719
#    245    "VAMP3"                43.3568    0.395287    2.97486
#    287    "GPR157"                0.480872  0.269076    2.51473
#    291    "H6PD"                  5.71485   0.325307    2.2516
#    292    "SPSB1"                 4.92211   0.367226    4.70519
#    312    "RBP7"           …      5.74945   0.325993   11.6139
#    324    "DFFA"                 11.9241    0.258403    1.69278
#    327    "CASZ1"                 0.522162  0.439353    4.28908
#      ⋮                     ⋱                            ⋮
#  55501    "SRPK3"          …      2.6826    0.275488    2.28275
#  55511    "RENBP"                 8.54283   0.360241    2.94352
#  55528    "FLNA"                 27.5654    0.419087    3.78439
#  55531    "RPL10"               435.816     0.415115    2.05397
#  55532    "SNORA70"              18.7465    0.381537    2.68312
#  55540    "PLXNA3"         …      5.99009   0.349544    2.65337
#  55580    "CLIC2"                 4.39634   0.400816    3.02502
#  56165    "MT-TV"                45.1551    0.0982682   5.73233
#  56181    "MT-CO2"            63155.5       0.32446     2.04245
#  56183    "MT-ATP8"           26514.0       0.250218    2.11595
#  56184    "MT-ATP6"        …  51824.3       0.247638    1.81295
#  56185    "MT-CO3"            53802.6       0.288801    2.07894

# %% [markdown]
# ## Save output file

# %%
# Set output directory
outdir = string(basedir, "/circa/CYCLOPS/baboon")
cd(outdir)
writecsv("Sig_Cosinor_ba9.csv", sig_cosinor_adj)

# %%
# Output estimated phases
colnames = ["SAMPID" "Estimated_Phase"]
samplephase = hcat(data[1,4:end], estimated_phaselist_adj)
output = vcat(colnames, samplephase)
writecsv("GTEx_estimatedPhase_ba9.csv", output)
